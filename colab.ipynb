# %% [markdown]
# # SRT Generator Pro - Google Colab
#
# Chạy tool tạo phụ đề trên Google Colab với giao diện Gradio.
#
# **Bước 1**: Chạy cell bên dưới để cài đặt
#
# **Bước 2**: Nhập API key từ https://console.groq.com/keys
#
# **Bước 3**: Sử dụng giao diện Gradio

# %%
# Clone repo và cài đặt dependencies
# !git clone https://github.com/YOUR_USERNAME/srt-gen-pro.git
# %cd srt-gen-pro
# !pip install -q gradio groq yt-dlp requests

# %%
# Import modules
import sys
sys.path.append('/content/srt-gen-pro')

from app import create_ui

# %%
# Chạy Gradio app
demo = create_ui()
demo.launch(
    share=True,  # Tạo public link
    show_error=True,
)
